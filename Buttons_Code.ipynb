# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
intro_1 = widgets.Label(value='Welcome to the team! We are glad to have your help to solve this case.')
intro_2 = widgets.Label(value='Please type your Case ID and press "Enter" to begin:')

enter_ID = widgets.IntText(
    value=0,
    disabled=False)

intro_ID = widgets.HBox([intro_2, enter_ID])
buttons = widgets.VBox([intro_1, intro_ID])
display(buttons)

# %%
enter_ID.value

# %%
# Create text widget for output
output_text = widgets.IntText()

# Create text widget for input
input_text = widgets.IntText()

# Define function to bind value of the input to the output variable 
def bind_input_to_output(sender):
    output_text.value = input_text.value

# Tell the text input widget to call bind_input_to_output() on submit
input_text.on_submit(bind_input_to_output)

# Display input text box widget for input
input_text
# Out:
# Text(value='')

# %%
# Display output text box widget (will populate when value submitted in input)
output_text
# Out:
# Text(value='')

# %%
from ipywidgets import interactive
from IPython.display import display

# Define any function
def f(a, b):
    return a + b

# Create sliders using interactive
my_result = interactive(f, a=(1,5), b=(6,10))

# You can also view this in a notebook without using display.
display(my_result)
# Out:
# interactive(children=(IntSlider(value=3, description='a', max=5, min=1), IntSlider(value=8, description='b', m…

# %%
my_result.result  # current value of returned object (in this case a+b)
my_result.children[0].value # current value of a
my_result.children[1].value # current value of b
# Out:
# 7

# %%
intro_4 = widgets.Label(value='Please review the information I gathered pertaining to this case, including the victim and the witnesses.')
intro_5 = widgest.Label(value='I also wanted to send you the initial police report filing. ')




u = widgets.Button(description="Dr. Emerald")
u_t = widgets.Label(value='Age: 59, Sex: Male')
v = widgets.Button(description="Mrs. Topaz")
v_t = widgets.Label(value='Age: 59, Sex: Female')
w = widgets.Button(description="Mr. Sapphire")
w_t = widgets.Label(value='Age: 28, Sex: Male')
x = widgets.Button(description="Prof. Amethyst")
x_t = widgets.Label(value='Age: 29, Sex: Female')
y = widgets.Button(description="Mr. Ruby")
y_t = widgets.Label(value='Age: 22, Sex: Male')
z = widgets.Button(description="View X-Ray")
z_t = widgets.Label(value='Victim')

u_box = widgets.HBox([u, u_t])
v_box = widgets.HBox([v, v_t])
w_box = widgets.HBox([w, w_t])
x_box = widgets.HBox([x, x_t])
y_box = widgets.HBox([y, y_t])
z_box = widgets.HBox([z, z_t])

image = open("example/start.png", "rb").read()
im = widgets.Image(value=image, format='png',
    width=150, height=150)

buttons = widgets.VBox([im, u_box, v_box, w_box, x_box, y_box, z_box])
display(buttons)

global click 
click = ''

@x.on_click
def x_clicked(a):
    global click
    click = click + 'x'
    updatebutton()

@y.on_click
def y_clicked(a):
    global click
    click = click + 'y'
    updatebutton()

@z.on_click    
def z_clicked(a):
    global click
    click = click + 'z'
    updatebutton()
       
def updatebutton():
    global click
#--------------------------------------
#--------------------------------------
    ###### A
    if click=='x':
        x.description = 'A1'
        x_t.value = 'text for A1'
        y.description = 'A2'
        y_t.value = 'text for A2'
        z.description = 'A3'
        z_t.value = 'text for A3'
        image = open("example/A.png", "rb").read()
        im.value=image
#--------------------------------------
#--------------------------------------
    #### A1
    if click=='xx':
        x.description = 'A1a'
        x_t.value = 'text for A1a'
        y.description = 'A1b'
        y_t.value = 'text for A1b'
        z.description = 'A1c'
        z_t.value = 'text for A1c'
        image = open("example/A1.png", "rb").read()
        im.value=image
    ## A1a
    if click=='xxx':
        x.description = 'A1a1'
        x_t.value = 'text for A1a1'
        y.description = 'A1a2'
        y_t.value = 'text for A1a2'
        z.description = 'A1a3'
        z_t.value = 'text for A1a3'
        image = open("example/A1a.png", "rb").read()
        im.value=image
    ## A1b
    if click=='xxy':
        x.description = 'A1b1'
        x_t.value = 'text for A1b1'
        y.description = 'A1b2'
        y_t.value = 'text for A1b2'
        z.description = 'A1b3'
        z_t.value = 'text for A1b3'
        image = open("example/A1b.png", "rb").read()
        im.value=image
    ## A1c
    if click=='xxz':
        x.description = 'A1c1'
        x_t.value = 'text for A1c1'
        y.description = 'A1c2'
        y_t.value = 'text for A1c2'
        z.description = 'A1c3'
        z_t.value = 'text for A1c3'
        image = open("example/A1c.png", "rb").read()
        im.value=image
#--------------------------------------        
    #### A2
    if click=='xy':
        x.description = 'A2a'
        x_t.value = 'text for A2a'
        y.description = 'A2b'
        y_t.value = 'text for A2b'
        z.description = 'A2c'
        z_t.value = 'text for A2c'
        image = open("example/A2.png", "rb").read()
        im.value=image
    ## A2a
    if click=='xyx':
        x.description = 'A2a1'
        x_t.value = 'text for A2a1'
        y.description = 'A2a2'
        y_t.value = 'text for A2a2'
        z.description = 'A2a3'
        z_t.value = 'text for A2a3' 
        image = open("example/A2a.png", "rb").read()
        im.value=image
    ## A2b
    if click=='xyy':
        x.description = 'A2b1'
        x_t.value = 'text for A2b1'
        y.description = 'A2b2'
        y_t.value = 'text for A2b2'
        z.description = 'A2b3'
        z_t.value = 'text for A2b3'
        image = open("example/A2b.png", "rb").read()
        im.value=image
    ## A2c
    if click=='xyz':
        x.description = 'A2c1'
        x_t.value = 'text for A2c1'
        y.description = 'A2c2'
        y_t.value = 'text for A2c2'
        z.description = 'A2c3'
        z_t.value = 'text for A2c3'
        image = open("example/A2c.png", "rb").read()
        im.value=image
#--------------------------------------        
    #### A3
    if click=='xz':
        x.description = 'A3a'
        x_t.value = 'text for A3a'
        y.description = 'A3b'
        y_t.value = 'text for A3b'
        z.description = 'A3c'
        z_t.value = 'text for A3c'
        image = open("example/A3.png", "rb").read()
        im.value=image
    ## A3a
    if click=='xzx':
        x.description = 'A3a1'
        x_t.value = 'text for A3a1'
        y.description = 'A3a2'
        y_t.value = 'text for A3a2'
        z.description = 'A3a3'
        z_t.value = 'text for A3a3'  
        image = open("example/A3a.png", "rb").read()
        im.value=image
    ## A3b
    if click=='xzy':
        x.description = 'A3b1'
        x_t.value = 'text for A3b1'
        y.description = 'A3b2'
        y_t.value = 'text for A3b2'
        z.description = 'A3b3'
        z_t.value = 'text for A3b3'
        image = open("example/A3b.png", "rb").read()
        im.value=image
    ## A3c
    if click=='xzz':
        x.description = 'A3c1'
        x_t.value = 'text for A3c1'
        y.description = 'A3c2'
        y_t.value = 'text for A3c2'
        z.description = 'A3c3'
        z_t.value = 'text for A3c3' 
        image = open("example/A3c.png", "rb").read()
        im.value=image
#--------------------------------------
#--------------------------------------        
    ###### B
    if click=='y': 
        x.description = 'B1'
        x_t.value = 'text for B1'
        y.description = 'B2'
        y_t.value = 'text for B2'
        z.description = 'B3'
        z_t.value = 'text for B3'
        image = open("example/B.png", "rb").read()
        im.value=image
#--------------------------------------
#--------------------------------------
    #### B1
    if click=='yx':
        x.description = 'B1a'
        x_t.value = 'text for B1a'
        y.description = 'B1b'
        y_t.value = 'text for B1b'
        z.description = 'B1c'
        z_t.value = 'text for B1c'
        image = open("example/B1.png", "rb").read()
        im.value=image
    ## B1a
    if click=='yxx':
        x.description = 'B1a1'
        x_t.value = 'text for B1a1'
        y.description = 'B1a2'
        y_t.value = 'text for B1a2'
        z.description = 'B1a3'
        z_t.value = 'text for B1a3'
        image = open("example/B1a.png", "rb").read()
        im.value=image
    ## B1b
    if click=='yxy':
        x.description = 'B1b1'
        x_t.value = 'text for B1b1'
        y.description = 'B1b2'
        y_t.value = 'text for B1b2'
        z.description = 'B1b3'
        z_t.value = 'text for B1b3'
        image = open("example/B1b.png", "rb").read()
        im.value=image
    ## B1c
    if click=='yxz':
        x.description = 'B1c1'
        x_t.value = 'text for B1c1'
        y.description = 'B1c2'
        y_t.value = 'text for B1c2'
        z.description = 'B1c3'
        z_t.value = 'text for B1c3'
        image = open("example/B1c.png", "rb").read()
        im.value=image
#--------------------------------------        
    #### B2
    if click=='yy':
        x.description = 'B2a'
        x_t.value = 'text for B2a'
        y.description = 'B2b'
        y_t.value = 'text for B2b'
        z.description = 'B2c'
        z_t.value = 'text for B2c'
        image = open("example/B2.png", "rb").read()
        im.value=image
    ## B2a
    if click=='yyx':
        x.description = 'B2a1'
        x_t.value = 'text for B2a1'
        y.description = 'B2a2'
        y_t.value = 'text for B2a2'
        z.description = 'B2a3'
        z_t.value = 'text for B2a3'
        image = open("example/B2a.png", "rb").read()
        im.value=image
    ## B2b
    if click=='yyy':
        x.description = 'B2b1'
        x_t.value = 'text for B2b1'
        y.description = 'B2b2'
        y_t.value = 'text for B2b2'
        z.description = 'B2b3'
        z_t.value = 'text for B2b3'
        image = open("example/B2b.png", "rb").read()
        im.value=image
    ## B2c
    if click=='yyz':
        x.description = 'B2c1'
        x_t.value = 'text for B2c1'
        y.description = 'B2c2'
        y_t.value = 'text for B2c2'
        z.description = 'B2c3'
        z_t.value = 'text for B2c3'
        image = open("example/B2c.png", "rb").read()
        im.value=image
#--------------------------------------        
    #### B3
    if click=='yz':
        x.description = 'B3a'
        x_t.value = 'text for B3a'
        y.description = 'B3b'
        y_t.value = 'text for B3b'
        z.description = 'B3c'
        z_t.value = 'text for B3c' 
        image = open("example/B3.png", "rb").read()
        im.value=image
    ## B3a
    if click=='yzx':
        x.description = 'B3a1'
        x_t.value = 'text for B3a1'
        y.description = 'B3a2'
        y_t.value = 'text for B3a2'
        z.description = 'B3a3'
        z_t.value = 'text for B3a3'
        image = open("example/B3a.png", "rb").read()
        im.value=image
    ## B3b
    if click=='yzy':
        x.description = 'B3b1'
        x_t.value = 'text for B3b1'
        y.description = 'B3b2'
        y_t.value = 'text for B3b2'
        z.description = 'B3b3'
        z_t.value = 'text for B3b3'
        image = open("example/B3b.png", "rb").read()
        im.value=image
    ## B3c
    if click=='yzz':
        x.description = 'B3c1'
        x_t.value = 'text for B3c1'
        y.description = 'B3c2'
        y_t.value = 'text for B3c2'
        z.description = 'B3c3'
        z_t.value = 'text for B3c3'
        image = open("example/B3c.png", "rb").read()
        im.value=image
#--------------------------------------
#--------------------------------------        
    ###### C
    if click=='z': 
        x.description = 'C1'
        x_t.value = 'text for C1'
        y.description = 'C2'
        y_t.value = 'text for C2'
        z.description = 'C3'
        z_t.value = 'text for C3'
        image = open("example/C.png", "rb").read()
        im.value=image
#--------------------------------------
#--------------------------------------
    #### C1
    if click=='zx':
        x.description = 'C1a'
        x_t.value = 'text for C1a'
        y.description = 'C1b'
        y_t.value = 'text for C1b'
        z.description = 'C1c'
        z_t.value = 'text for C1c'
        image = open("example/C1.png", "rb").read()
        im.value=image
    ## C1a
    if click=='zxx':
        x.description = 'C1a1'
        x_t.value = 'text for C1a1'
        y.description = 'C1a2'
        y_t.value = 'text for C1a2'
        z.description = 'C1a3'
        z_t.value = 'text for C1a3'
        image = open("example/C1a.png", "rb").read()
        im.value=image
    ## C1b
    if click=='zxy':
        x.description = 'C1b1'
        x_t.value = 'text for C1b1'
        y.description = 'C1b2'
        y_t.value = 'text for C1b2'
        z.description = 'C1b3'
        z_t.value = 'text for C1b3'
        image = open("example/C1b.png", "rb").read()
        im.value=image
    ## C1c
    if click=='zxz':
        x.description = 'C1c1'
        x_t.value = 'text for C1c1'
        y.description = 'C1c2'
        y_t.value = 'text for C1c2'
        z.description = 'C1c3'
        z_t.value = 'text for C1c3'
        image = open("example/C1c.png", "rb").read()
        im.value=image
#--------------------------------------        
    #### C2
    if click=='zy':
        x.description = 'C2a'
        x_t.value = 'text for C2a'
        y.description = 'C2b'
        y_t.value = 'text for C2b'
        z.description = 'C2c'
        z_t.value = 'text for C2c'
        image = open("example/C2.png", "rb").read()
        im.value=image
    ## C2a
    if click=='zyx':
        x.description = 'C2a1'
        x_t.value = 'text for C2a1'
        y.description = 'C2a2'
        y_t.value = 'text for C2a2'
        z.description = 'C2a3'
        z_t.value = 'text for C2a3'
        image = open("example/C2a.png", "rb").read()
        im.value=image
    ## C2b
    if click=='zyy':
        x.description = 'C2b1'
        x_t.value = 'text for C2b1'
        y.description = 'C2b2'
        y_t.value = 'text for C2b2'
        z.description = 'C2b3'
        z_t.value = 'text for C2b3'
        image = open("example/C2b.png", "rb").read()
        im.value=image
    ## C2c
    if click=='zyz':
        x.description = 'C2c1'
        x_t.value = 'text for C2c1'
        y.description = 'C2c2'
        y_t.value = 'text for C2c2'
        z.description = 'C2c3'
        z_t.value = 'text for C2c3'
        image = open("example/C2c.png", "rb").read()
        im.value=image
#--------------------------------------        
    #### C3
    if click=='zz':
        x.description = 'C3a'
        x_t.value = 'text for C3a'
        y.description = 'C3b'
        y_t.value = 'text for C3b'
        z.description = 'C3c'
        z_t.value = 'text for C3c'
        image = open("example/C3.png", "rb").read()
        im.value=image
    ## C3a
    if click=='zzx':
        x.description = 'C3a1'
        x_t.value = 'text for C3a1'
        y.description = 'C3a2'
        y_t.value = 'text for C3a2'
        z.description = 'C3a3'
        z_t.value = 'text for C3a3'  
        image = open("example/C3a.png", "rb").read()
        im.value=image
    ## C3b
    if click=='zzy':
        x.description = 'C3b1'
        x_t.value = 'text for C3b1'
        y.description = 'C3b2'
        y_t.value = 'text for C3b2'
        z.description = 'C3b3'
        z_t.value = 'text for C3b3'
        image = open("example/C3b.png", "rb").read()
        im.value=image
    ## C3c
    if click=='zzz':
        x.description = 'C3c1'
        x_t.value = 'text for C3c1'
        y.description = 'C3c2'
        y_t.value = 'text for C3c2'
        z.description = 'C3c3'
        z_t.value = 'text for C3c3'
        image = open("example/C3c.png", "rb").read()
        im.value=image
#--------------------------------------
#--------------------------------------
    if len(click)==4:
        image = open("example/end.png", "rb").read()
        im.value=image
    # clear buttons / done
        if click[-1]=='x':
            to_print = x.description  
        if click[-1]=='y':
            to_print = y.description
        if click[-1]=='z':
            to_print = z.description
        x.close()
        x_t.close()
        y.close()
        y_t.close()
        z.close()
        z_t.close()
        display(to_print)
