# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, YouTubeVideo

# %%
global click, case 
click = ''
case = '0'
####################################################################################
#--------- INTRO ENTER CASE --------------
intro_1 = widgets.Label(value='Welcome to the team! We are glad to have your help to solve this case.')
intro_2 = widgets.HTML(value="Please enter your <b>Case ID:</b>")
intro_3 = widgets.HTML(value="Please enter your <b>Progress Code:</b>")
enter_ID = widgets.Text()
enter_Prog = widgets.Text()
Start = widgets.Button(description='START',disabled=False)
intro_4 = widgets.HTML(value="Confirm Case ID and Progress Code are correct, then press:")

ID_box = widgets.HBox([intro_2, enter_ID])
Prog_box = widgets.HBox([intro_3, enter_Prog])
Start_box = widgets.HBox([intro_4, Start])

box_layout = widgets.Layout(border='solid')
button_intro = widgets.VBox([intro_1, ID_box, Prog_box, Start_box],layout=box_layout)

disp_intro = widgets.VBox([button_intro])
#!!#!!#!!#
display(disp_intro)

#--------- PROGRESS CODE ---------------
P = widgets.Text()
P_t = widgets.Label(value="Progress Code:")

disp_prog = widgets.HBox([P_t, P],layout=box_layout)

#--------- EVIDENCE BUTTONS---------------
Blank_im = open("Blank.png", "rb").read()   

I = widgets.Button(description="Initial Report Filing",style={'font_weight':'bold'})
#!# add in Report image here
#I_im = open("I.png", "rb").read()
#It.value=X_im
I_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)
V = widgets.Button(description="Victim Information",style={'font_weight':'bold'})
V_t = widgets.Image(value=Blank_im, format='png', width=50, height=60)
E = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'})
E_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)
T = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'})
T_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)
S = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'})
S_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)
A = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'})
A_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)
R = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'})
R_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)
X = widgets.Button(disabled=True,style={'button_color':'#FFFFFF'})
X_t = widgets.Image(value=Blank_im, format='png', width=50, height=50)

box_layout = widgets.Layout(align_items='center')

case_info = widgets.HTML(value="<b>Case Information:</b>")
I_box = widgets.HBox([I, I_t],layout=box_layout)
V_box = widgets.HBox([V, V_t],layout=box_layout)
witness = widgets.HTML(value = "<b>Interview Witnesses:</b>")
E_box = widgets.HBox([E, E_t],layout=box_layout)
T_box = widgets.HBox([T, T_t],layout=box_layout)
S_box = widgets.HBox([S, S_t],layout=box_layout)
A_box = widgets.HBox([A, A_t],layout=box_layout)
R_box = widgets.HBox([R, R_t],layout=box_layout)
view = widgets.HTML(value="<b>View Medical Information:</b>")
X_box = widgets.HBox([X, X_t],layout=box_layout)

disp_evid_buttons = widgets.VBox([case_info, I_box, V_box, witness, E_box, T_box, S_box, A_box, R_box, 
                                view, X_box])

#--------- EVIDENCE INFORMATION --------------
textbox_title = widgets.HTML(value='')
textbox_top = widgets.HTML(value='')
video_middle = widgets.HTML(value='')
textbox_bottom = widgets.HTML(value='')

disp_evid_info = widgets.VBox([textbox_title,textbox_top,video_middle,textbox_bottom])

####################################################################################
##########
@Start.on_click
def Start_clicked(a):
    global click, case
    
    case = enter_ID.value
    click = enter_Prog.value

    prog_correct = 1
##--Check Progress Code 
    if len(click)!=0:
        # checks if all uppercase & if all letters
        if click.isupper() == False or click.isalpha() == False:
            prog_correct = 0
            
        # if passed above, then check specific lettters/duplicates    
        if prog_correct == 1:
            for i in range(len(click)):
                l = click[i] 

                # 'I', 'V', 'IV' or 'VI' must be only options for first
                if len(click)==1:
                    if click != 'I' and click != 'V':
                        prog_correct = 0
                else:    
                    if click[0:2] != 'IV' and click[0:2] != 'VI':
                        prog_correct = 0

                # specific letters
                if l != 'I' and l != 'V' and l != 'E' and l != 'T' and l != 'S' and l != 'A' and l != 'R' and l != 'X':
                    prog_correct = 0

                # duplicates
                if click.find(l) != i:
                    prog_correct = 0
    
    case_correct = 0
##--Check Case Number
    if case == '1' or case == '2' or case == '3' or case == '4':
        case_correct = 1

#---#---------------------
    if prog_correct == 1 and case_correct == 1:
        
        intro_4.value = "Confirm Case ID and Progress Code are correct, then press:"
        case_info.value="<b>Case #" + case + " Information:</b>"
        
        
        if case == '1':
            V.style = {'button_color':'#F7A6A0','font_weight':'bold'}
            V_t.value = open("Ja.png", "rb").read()
        elif case == '2':
            V.style = {'button_color':'#94BFAB','font_weight':'bold'}
            V_t.value = open("Jo.png", "rb").read()
        elif case == '3':
            V.style = {'button_color':'#FAB190','font_weight':'bold'}
            V_t.value = open("Cy.png", "rb").read()
        elif case == '4':
            V.style = {'button_color':'#FFDD9C','font_weight':'bold'}
            V_t.value=open("Mi.png", "rb").read()
        
        
        disp_evid = widgets.HBox([disp_evid_buttons,disp_evid_info])
        #!!#!!#!!#
        display(disp_evid)
        display(disp_prog)
    
        if click == '' or click == 'I' or click == 'V':
            # Start of case -- still only show initial disp_intro
            Start.disabled = True
        else:
            Start.disabled = True
            witnessbutton()            
    
        # progress code
        if click.find('I') > -1:
            I.style = {'button_color':'#A5A5A5'}
        if click.find('V') > -1:
            V.style = {'button_color':'#A5A5A5'}
        if click.find('E') > -1:
            E.style = {'button_color':'#A5A5A5'}
        if click.find('T') > -1:
            T.style = {'button_color':'#A5A5A5'} 
        if click.find('S') > -1:
            S.style = {'button_color':'#A5A5A5'} 
        if click.find('A') > -1:
            A.style = {'button_color':'#A5A5A5'} 
        if click.find('R') > -1:
            R.style = {'button_color':'#A5A5A5'} 
        if click.find('X') > -1:
            X.style = {'button_color':'#A5A5A5'}  

#---#--------------------- 
    elif case_correct == 0 and prog_correct == 1:
        intro_4.value = "<font color='red'><b>ERROR: Incorrect Case ID</font color></b>"
#---#--------------------- 
    elif case_correct == 1 and prog_correct == 0:
        intro_4.value = "<font color='red'><b>ERROR: Incorrect Progress Code</font color></b>"
#---#--------------------- 
    else:
        intro_4.value = "<font color='red'><b>ERROR: Incorrect Progress Code and Case ID</font color></b>"                              
        
##########        
@E.on_click
def E_clicked(a):
    global click, case
    click = click + 'E'
    updatebutton()

##########
@T.on_click
def v_clicked(a):
    global click, case
    click = click + 'T'
    updatebutton()

##########
@S.on_click    
def S_clicked(a):
    global click, case
    click = click + 'S'
    updatebutton()

##########
@A.on_click
def A_clicked(a):
    global click, case
    click = click + 'A'
    updatebutton()

##########
@R.on_click
def R_clicked(a):
    global click, case
    click = click + 'R'
    updatebutton()

##########
@X.on_click    
def X_clicked(a):
    global click, case
    click = click + 'X'
    updatebutton()

##########
@I.on_click    
def I_clicked(a):
    global click, case
    click = click + 'I'
    updatebutton()
    
##########
@V.on_click    
def V_clicked(a):
    global click, case
    click = click + 'V'
    updatebutton()

##########
def witnessbutton():
    global click, case
    #---
    E.description="Dr. Emerald"
    E.style={'button_color':'#8BA09D','font_weight':'bold'}
    E_t.value = open("E.png", "rb").read()
    E.disabled = False
    #---
    T.description="Mrs. Topaz"
    T.style={'button_color':'#DABA88','font_weight':'bold'}
    T_t.value = open("T.png", "rb").read()
    T.disabled = False
    #---
    S.description="Mr. Sapphire"
    S.style={'button_color':'#8589B2','font_weight':'bold'}
    S_t.value = open("S.png", "rb").read()
    S.disabled = False
    #---
    A.description="Prof. Amethyst"
    A.style={'button_color':'#BB8CAB','font_weight':'bold'}
    A_t.value = open("A.png", "rb").read()
    A.disabled = False
    #---
    R.description="Mr. Ruby"
    R.style={'button_color':'#BA8178','font_weight':'bold'}
    R_t.value = open("R.png", "rb").read()
    R.disabled = False
    #---
    X.description="View X-Ray"
    X.style={'button_color':'#D3D3D3','font_weight':'bold'}
    X.disabled=False
    #---
    #!# add in XRay Image here
    #X_t.value = open("X.png", "rb").read()

##########
def updatebutton():
    global click, case
#--------------------------------------
    if click[-1] == 'E':      
        # if duplicate button, remove from click string
        if click.find('E') < (len(click)-1):
            click = click[:-1]
        
        P.value = click        
        textbox_title.value = "<b>Interview Dr. Emerald</b><br>Age: 59<br>Height: 5ft 11in<br>Sex: Male"
        E.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 information for Dr. Emerald"
            video_middle.value = "<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/S5Vz-z4PEkk?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '2':
            textbox_top.value = "Case 2 information for Dr. Emerald" 
            video_middle.value= "<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/S5Vz-z4PEkk?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '3':
            textbox_top.value = "Case 3 information for Dr. Emerald" 
            video_middle.value= "<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/S5Vz-z4PEkk?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '4':
            textbox_top.value = "Case 4 information for Dr. Emerald" 
            video_middle.value= "<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/S5Vz-z4PEkk?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        
#--------------------------------------
    elif click[-1] == 'T':
        # if duplicate button, remove from click string
        if click.find('T') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>Interview Mrs. Topaz</b><br>Age: 59<br>Height: 5ft 7in<br>Sex: Female"
        T.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 information for Mrs. Topaz"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/m2uTFF_3MaA?start=37&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '2':
            textbox_top.value = "Case 2 information for Mrs. Topaz"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/m2uTFF_3MaA?start=37&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '3':
            textbox_top.value = "Case 3 information for Mrs. Topaz"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/m2uTFF_3MaA?start=37&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '4':
            textbox_top.value = "Case 4 information for Mrs. Topaz"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/m2uTFF_3MaA?start=37&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        
#--------------------------------------
    elif click[-1] == 'S':
        # if duplicate button, remove from click string
        if click.find('S') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>Interview Mr. Sapphire</b><br>Age: 28<br>Height: 6ft 3in<br>Sex: Male"
        S.style = {'button_color':'#A5A5A5'}

        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 information for Mr. Sapphire"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/68ugkg9RePc?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '2':
            textbox_top.value = "Case 2 information for Mr. Sapphire"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/68ugkg9RePc?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '3':
            textbox_top.value = "Case 3 information for Mr. Sapphire"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/68ugkg9RePc?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '4':
            textbox_top.value = "Case 4 information for Mr. Sapphire"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/68ugkg9RePc?start=33&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        
#--------------------------------------
    elif click[-1] == 'A':
        # if duplicate button, remove from click string
        if click.find('A') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>Interview Prof. Amethyst</b><br>Age: 29<br>Height: 5ft 3in<br>Sex: Female"
        A.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 information for Prof. Amethyst"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/TvnYmWpD_T8?start=115&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '2':
            textbox_top.value = "Case 2 information for Prof. Amethyst"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/TvnYmWpD_T8?start=115&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '3':
            textbox_top.value = "Case 3 information for Prof. Amethyst"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/TvnYmWpD_T8?start=115&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '4':
            textbox_top.value = "Case 4 information for Prof. Amethyst"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/TvnYmWpD_T8?start=115&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
            
#--------------------------------------
    elif click[-1] == 'R':
        # if duplicate button, remove from click string
        if click.find('R') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>Interview Mr. Ruby</b><br>Age: 22<br>Height: 6ft 2in<br>Sex: Male"
        R.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 information for Mr. Ruby"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/Q86nf7mpOXk?start=71&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '2':
            textbox_top.value = "Case 2 information for Mr. Ruby"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/Q86nf7mpOXk?start=71&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '3':
            textbox_top.value = "Case 3 information for Mr. Ruby"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/Q86nf7mpOXk?start=71&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        elif case == '4':
            textbox_top.value = "Case 4 information for Mr. Ruby"
            video_middle.value="<iframe width='560' height='315'\
                src='https://www.youtube-nocookie.com/embed/Q86nf7mpOXk?start=71&modestbranding=1&autoplay=1&rel=0'\
                frameborder='0' allow='accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture'\
                allowfullscreen></iframe>"
            textbox_bottom.value="More text can go here"
        
#--------------------------------------
    elif click[-1] == 'X':
        # if duplicate button, remove from click string
        if click.find('X') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>View X-Ray</b>"
        X.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 X-Ray"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '2':
            textbox_top.value = "Case 2 X-Ray"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '3':
            textbox_top.value = "Case 3 X-Ray"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '4':
            textbox_top.value = "Case 4 X-Ray"
            video_middle.value=""
            textbox_bottom.value=""
        
#--------------------------------------
    elif click[-1] == 'I':
        # if duplicate button, remove from click string
        if click.find('I') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>Intial Report Filing</b>"
        I.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 Initial Report"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '2':
            textbox_top.value = "Case 2 Initial Report"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '3':
            textbox_top.value = "Case 3 Initial Report"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '4':
            textbox_top.value = "Case 4 Initial Report"
            video_middle.value=""
            textbox_bottom.value=""
        
        #----------------------
        if click.find('V') > -1:
            # both I & V clicked
            witnessbutton()
        
#--------------------------------------
    elif click[-1] == 'V':
        # if duplicate button, remove from click string
        if click.find('V') < (len(click)-1):
            click = click[:-1]
        
        P.value = click 
        textbox_title.value = "<b>Victim Information</b>"
        V.style = {'button_color':'#A5A5A5'}
        
        #----------------------
        if case == '1':
            textbox_top.value = "Case 1 Victim (Jane Doe) Information"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '2':
            textbox_top.value = "Case 2 Victim (John Doe) Information"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '3':
            textbox_top.value = "Case 3 Victim (Cynthia Doe) Information"
            video_middle.value=""
            textbox_bottom.value=""
        elif case == '4':
            textbox_top.value = "Case 4 Victim (Michael Doe) Information"
            video_middle.value=""
            textbox_bottom.value=""
            
        #----------------------
        if click.find('I') > -1:
            # both I & V clicked
            witnessbutton()
